# %%
axs[1].plot(x, y, marker='o', color='blue', linewidth=2)

axs[1].set_xlim(0, 10)
axs[1].set_ylim(0, 20)
axs[1].set_xticks(np.arange(0, 11, 1))
axs[1].set_yticks(np.arange(0, 21, 5))

axs[1].set_xlabel("Sumbu Waktu (Tahun)", fontsize=12)
axs[1].set_ylabel("Indikator Ekonomi (Nilai)", fontsize=12)
axs[1].set_title("Pergerakan Indikator Ekonomi", fontsize=14)

axs[1].grid(True, which='both', linestyle='--', linewidth=0.5)

axs[1].spines['top'].set_visible(False)
axs[1].spines['right'].set_visible(False)
